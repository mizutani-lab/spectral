# %%
import networkx as nx
import numpy as np
from numpy.linalg import eig
import sympy as sp

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)

# %%
import easy_plotly as ep

# %%
def plot_eig_vec(G):
    L = nx.laplacian_matrix(G).toarray()
    w, v = eig(L)
    idx = np.argsort(w)
    w, v = w[idx], v[:, idx]

    fig = ep.PlotlyFigure('./scatter.yml', x_title='$\psi_2$', y_title='$\psi_3$')
    fig.add_scatter(v[1], v[2], marker_color=list(range(len(G))), marker_colorscale="RdBu")
    fig.to_png(show=True)
    
    fig2 = ep.PlotlyFigure('./scatter.yml', x_title='$i$', y_title='eigenvalues')
    fig2.add_scatter(list(range(1, len(G) + 1)), w, marker_color=list(range(len(G))), marker_colorscale="RdBu")
    fig2.to_png(show=True)

# %%
plot_eig_vec(nx.cycle_graph(200))

# %%
plot_eig_vec(nx.path_graph(200))
